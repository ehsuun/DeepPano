# %%
import argparse
import os
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from PIL import Image

# %%
import models

# %%
# Default input size

height = 512
width = 512
channels = 3
batch_size = 1
input_node = None
net = None
image_path = "room.jpg"
model_data_path = "models/NYU_ResNet-UpProj.npy"

# %%
# Read image
img = Image.open(image_path)
img = img.resize([width,height], Image.ANTIALIAS)
img = np.array(img).astype('float32')
img = np.expand_dims(np.asarray(img), axis = 0)

# %%
# Create a placeholder for the input image
input_node = tf.placeholder(tf.float32, shape=(None, height, width, channels))

# Construct the network
net = models.ResNet50UpProj({'data': input_node}, batch_size, 1, False)

# %%
sess = tf.Session()
# Load the converted parameters
print('Loading the model')

# Use to load from ckpt file
#saver = tf.train.Saver()     
#saver.restore(sess, model_data_path)

# Use to load from npy file
net.load(model_data_path, sess)
# Out:
# Loading the model

# %%
# Evalute the network for the given image
pred = sess.run(net.get_output(), feed_dict={input_node: img})

# %%
# Plot result
fig = plt.figure()
ii = plt.imshow(pred[0,:,:,0], interpolation='nearest')
fig.colorbar(ii)
plt.show()

# %%
image_path = "skybox/nz.png"
# Read image
img = Image.open(image_path)
img = img.resize([width,height], Image.ANTIALIAS)
img = np.array(img).astype('float32')
img = np.expand_dims(np.asarray(img), axis = 0)

pred = sess.run(net.get_output(), feed_dict={input_node: img})
# Plot result
fig = plt.figure()
ii = plt.imshow(pred[0,:,:,0], interpolation='nearest')
fig.colorbar(ii)
plt.show()

# %%
from numpy import array

# %%
image_path = "skybox/px.jpg"
# Read image
img = Image.open(image_path)
img = img.resize([width,height], Image.ANTIALIAS)
plt.imshow(img,interpolation="bicubic")
img = np.array(img).astype('float32')
img = np.expand_dims(np.asarray(img), axis = 0)



pred = sess.run(net.get_output(), feed_dict={input_node: img})
# Plot result
fig = plt.figure()
ii = plt.imshow(pred[0,:,:,0], interpolation='nearest')
fig.colorbar(ii)
plt.show()

res = pred[0].flatten()
res = np.repeat(res,4)
res.astype('float32').tofile(image_path+'.bytes')

# %%
image_path = "skybox/nx.jpg"
# Read image
img = Image.open(image_path)
img = img.resize([width,height], Image.ANTIALIAS)
plt.imshow(img,interpolation="bicubic")
img = np.array(img).astype('float32')
img = np.expand_dims(np.asarray(img), axis = 0)



pred = sess.run(net.get_output(), feed_dict={input_node: img})
# Plot result
fig = plt.figure()
ii = plt.imshow(pred[0,:,:,0], interpolation='nearest')
fig.colorbar(ii)
plt.show()

res = pred[0].flatten()
res = np.repeat(res,4)
res.astype('float32').tofile(image_path+'.bytes')

# %%
image_path = "skybox/py.jpg"
# Read image
img = Image.open(image_path)
img = img.resize([width,height], Image.ANTIALIAS)
plt.imshow(img,interpolation="bicubic")
img = np.array(img).astype('float32')
img = np.expand_dims(np.asarray(img), axis = 0)



pred = sess.run(net.get_output(), feed_dict={input_node: img})
# Plot result
fig = plt.figure()
ii = plt.imshow(pred[0,:,:,0], interpolation='nearest')
fig.colorbar(ii)
plt.show()

res = pred[0].flatten()
res = np.repeat(res,4)
res.astype('float32').tofile(image_path+'.bytes')

# %%
image_path = "skybox/ny.jpg"
# Read image
img = Image.open(image_path)
img = img.resize([width,height], Image.ANTIALIAS)
plt.imshow(img,interpolation="bicubic")
img = np.array(img).astype('float32')
img = np.expand_dims(np.asarray(img), axis = 0)



pred = sess.run(net.get_output(), feed_dict={input_node: img})
# Plot result
fig = plt.figure()
ii = plt.imshow(pred[0,:,:,0], interpolation='nearest')
fig.colorbar(ii)
plt.show()

res = pred[0].flatten()
res = np.repeat(res,4)
res.astype('float32').tofile(image_path+'.bytes')

# %%
image_path = "skybox/pz.jpg"
# Read image
img = Image.open(image_path)
img = img.resize([width,height], Image.ANTIALIAS)
plt.imshow(img,interpolation="bicubic")
img = np.array(img).astype('float32')
img = np.expand_dims(np.asarray(img), axis = 0)



pred = sess.run(net.get_output(), feed_dict={input_node: img})
# Plot result
fig = plt.figure()
ii = plt.imshow(pred[0,:,:,0], interpolation='nearest')
fig.colorbar(ii)
plt.show()

res = pred[0].flatten()
res = np.repeat(res,4)
res.astype('float32').tofile(image_path+'.bytes')

# %%
image_path = "skybox/nz.jpg"
# Read image
img = Image.open(image_path)
img = img.resize([width,height], Image.ANTIALIAS)
plt.imshow(img,interpolation="bicubic")
img = np.array(img).astype('float32')
img = np.expand_dims(np.asarray(img), axis = 0)



pred = sess.run(net.get_output(), feed_dict={input_node: img})
# Plot result
fig = plt.figure()
ii = plt.imshow(pred[0,:,:,0], interpolation='nearest')
fig.colorbar(ii)
plt.show()

res = pred[0].flatten()
res = np.repeat(res,4)
res.astype('float32').tofile(image_path+'.bytes')
